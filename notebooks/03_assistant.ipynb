# %% [markdown]
# # 03 - Conversational Assistant (RAG + Rules)

# %%
from becas_rd.assistant import chat_assistant
applicant = {
    'edad': 24, 'genero': 'femenino', 'provincia': 'San Juan', 'region': 'El Valle',
    'zona': 'rural', 'tipo_beca': 'internacional', 'nivel_estudio': 'maestria',
    'ingreso_hogar_mensual_dop': 38000, 'miembros_hogar': 5,
    'promedio_academico': 91, 'score_documental': 88, 'horas_voluntariado': 110,
    'puntaje_ingles': 84, 'costo_anual_programa_dop': 1500000,
    'primera_generacion_universitaria': 1, 'discapacidad': 0
}
chat_assistant('Soy elegible y que documentos necesito?', applicant_context=applicant, artifacts_path='../artifacts/model_bundle.joblib')
