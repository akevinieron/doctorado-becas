# %% [markdown]
# # 04 - Report Assets Export

# %%
from becas_rd.report_assets import export_report_assets
export_report_assets('../artifacts/metrics.json', '../artifacts/fairness.json', '../report/assets')
