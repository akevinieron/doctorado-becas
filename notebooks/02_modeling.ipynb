# %% [markdown]
# # 02 - Modeling and Fairness

# %%
import pandas as pd
from becas_rd.modeling import train_models
df = pd.read_csv('../data/synthetic_becas_rd.csv')
res = train_models(df, artifacts_dir='../artifacts')
res.metrics
