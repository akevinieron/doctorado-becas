# %% [markdown]
# # 01 - Data Generation (Synthetic Becas RD)

# %%
# !pip install -r ../requirements.txt

# %%
from becas_rd.data_generation import GenerationConfig, save_synthetic_dataset
df = save_synthetic_dataset('../data/synthetic_becas_rd.csv', GenerationConfig(n_samples=3000, random_state=42))
df.head()
